# %% [markdown]
# ***End-to-End Data Analysis and Reporting Project***

# %%
# Import library
import pandas as pd

# Load the data set
df = pd.read_excel('global_superstore_2016.xlsx')

# Print the first five rows
print(df.head())
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
# Import library
import pandas as pd

# Load "Orders"
file_path = 'global_superstore_2016.xlsx'  
df = pd.read_excel(file_path, sheet_name='Orders')

# Print the first 5 rows
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
# Check for the number of rows and columns
print("Shape:", df.shape)

# Print column names and data types
df.info()
# Out:
# Shape: (51290, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
# Check the missing values in each column
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
# Check the data types. For dates, it should be (datetime64[ns]).
print(df['Order Date'].dtype)
print(df['Ship Date'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
# Clean up the column names by:
# - Removing spaces at the start or end of each name
# - Making all letters lowercase
# - Replacing spaces inside names with underscores so they are easier to use in code
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# Print new column names
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'postal_code', 'city',
#        'state', 'country', 'region', 'market', 'product_id', 'category',
#        'sub-category', 'product_name', 'sales', 'quantity', 'discount',
#        'profit', 'shipping_cost', 'order_priority'],
#       dtype='object')

# %% [markdown]
# **Data Cleaning Summary**:
# - Dataset: Global Superstore 2016
# Source: Edureka course materials (Learning Management System)
#
# - All column names were loaded into the dataset.
#
# - I used Pandas to load the "Orders" sheet from the global_superstore_2016.xlsx file.
#
# - I examined the dataset's shape, and I discovered that it contains over 9,000 rows and 24 columns.
#
# - To make it easier to work with in Python, all column names have been changed to lowercase and spaces have been substituted with underscores.
#
# - I confirmed that the order_date and ship_date columns were formatted as dates correctly.
#
# - I discovered that 41,296 out of approximately 10,000 rows in the postal_code column are missing values and I chose to leave this column for the time being because it won't have an impact on my primary sales analysis and isn't utilised in my dashboard.
#
# - There were no missing values in any other columns.

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Get the total Sales and total Profit
total_sales = df['sales'].sum()
total_profit = df['profit'].sum()

# Print the results
print(f"Total Sales: R{total_sales:,.2f}")
print(f"Total Profit: R{total_profit:,.2f}")
# Out:
# Total Sales: R12,642,501.91
# Total Profit: R1,467,457.29

# %%
# Group the data by 'region'
# Calculate the total sales for each region
# Then, sort the results from highest to lowest sales
sales_by_region = df.groupby('region')['sales'].sum().sort_values(ascending=False)
print(sales_by_region)
# Out:
# region
# Western Europe       1.731930e+06
# Central America      1.223101e+06
# Oceania              1.100185e+06
# Southeastern Asia    8.844232e+05
# Southern Asia        8.665727e+05
# Eastern Asia         8.550594e+05
# Western US           7.254578e+05
# Eastern US           6.787812e+05
# Northern Europe      6.367792e+05
# South America        6.172237e+05
# Southern Europe      6.085940e+05
# Central US           5.012399e+05
# Southern US          3.917219e+05
# Caribbean            3.242809e+05
# Western Asia         3.171070e+05
# Eastern Europe       3.100334e+05
# North Africa         2.332166e+05
# Western Africa       1.738788e+05
# Central Africa       1.436300e+05
# Eastern Africa       1.278560e+05
# Southern Africa      1.051918e+05
# Canada               6.692817e+04
# Central Asia         1.931146e+04
# Name: sales, dtype: float64

# %% [markdown]
# **Sales by Region Bar Chart**

# %%
# Import library
import matplotlib.pyplot as plt

# Plot the chart
plt.figure(figsize=(10,6))
ax = sales_by_region.plot(kind='bar', color='orchid', edgecolor='lightpink', linewidth=2)
plt.title('Sales by Region', fontsize=18, fontweight='bold', color='purple')
plt.xlabel('Region', fontsize=14)
plt.ylabel('Total Sales', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Sales by Profit Bar Chart**

# %%
# Group the data by 'category'
# Calculate the total sales and total profit for each category
# Then sort the categories by total sales in descending order 
category_summary = df.groupby('category')[['sales', 'profit']].sum().sort_values(by='sales', ascending=False)

# Print the results
print(category_summary)
# Out:
#                         sales        profit
# category
# Technology       4.744557e+06  663778.73318
# Furniture        4.110452e+06  285082.73020
# Office Supplies  3.787493e+06  518595.82790

# %%
# Plot
colors = ['orchid', 'pink']
category_summary.plot(kind='bar', figsize=(8,5), color=colors, edgecolor='lightpink', linewidth=2)
plt.title('Sales and Profit by Category', fontsize=16, fontweight='bold', color='purple')
plt.ylabel('Amount')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Top 10 Products by Sales Bar Chart**

# %%
# Group the data by 'product_name'
# Calculate the total sales for each product
# Sort the products by sales in descending order 
# Select the top 10 products with the highest sales
top_products = df.groupby('product_name')['sales'].sum().sort_values(ascending=False).head(10)

# Print the top 10 products and their total sales
print(top_products)

# Plot a horizontal bar plot for the top 10 products by sales
top_products.plot(kind='barh', figsize=(8,5), color='orchid', edgecolor='pink', linewidth=2)

# Add a title 
plt.title('Top 10 Products by Sales', fontsize=16, fontweight='bold', color='purple')

# Label the x-axis as 'Sales' 
plt.xlabel('Sales')

plt.gca().invert_yaxis()

plt.tight_layout()

# Show the plot
plt.show()
# Out:
# product_name
# Apple Smart Phone, Full Size                                86935.7786
# Cisco Smart Phone, Full Size                                76441.5306
# Motorola Smart Phone, Full Size                             73156.3030
# Nokia Smart Phone, Full Size                                71904.5555
# Canon imageCLASS 2200 Advanced Copier                       61599.8240
# Hon Executive Leather Armchair, Adjustable                  58193.4841
# Office Star Executive Leather Armchair, Adjustable          50661.6840
# Harbour Creations Executive Leather Armchair, Adjustable    50121.5160
# Samsung Smart Phone, Cordless                               48653.4600
# Nokia Smart Phone, with Caller ID                           47877.7857
# Name: sales, dtype: float64

# %% [markdown]
# **Sales Distribution by Segment Pie Chart**

# %%
# Import library
import matplotlib.pyplot as plt

# Group the sales data by 'Segment' and calculate the total sales for each segment
segment_sales = df.groupby('segment')['sales'].sum()

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(segment_sales, labels=segment_sales.index, autopct='%1.1f%%', colors=['orchid','pink','plum'], shadow=True, textprops={'fontsize':14}, wedgeprops={'edgecolor':'white'}, startangle=140)
plt.title('Sales Distribution by Segment', fontsize=16, fontweight='bold', color='purple')
plt.show()

# %% [markdown]
# **Correlation of Numerical Features Heatmap**

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Keep only numeric columns for correlation
num_cols = ['sales', 'quantity', 'discount', 'profit', 'shipping_cost']
corr_matrix = df[num_cols].corr()

# Plot the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='magma', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features', fontsize=16, fontweight='bold', color='purple')
plt.show()

# %% [markdown]
# **Monthly Sales Trend Line Chart**

# %%
# Ensure 'order_date' is datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Create a new column for Year-Month
df['year_month'] = df['order_date'].dt.to_period('M')

# Group by Year-Month and calculate total sales
monthly_sales = df.groupby('year_month')['sales'].sum().reset_index()

# Convert Period to datetime for plotting
monthly_sales['year_month'] = monthly_sales['year_month'].dt.to_timestamp()

# %%
# Import library
import matplotlib.pyplot as plt

# Plot
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales['year_month'], monthly_sales['sales'], marker='o', color='orchid', linewidth=2, markerfacecolor='pink')
plt.title('Monthly Sales Trend', fontsize=16, fontweight='bold', color='purple')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45, ha='right')

for x, y in zip(monthly_sales['year_month'], monthly_sales['sales']):
    plt.text(x, y, f'{int(y):,}', ha='center', va='bottom', fontsize=6)



plt.show()

# %%
**Sales Distribution by Region Boxplot**

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Plot 
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='region', y='sales', palette='pastel')
plt.title('Sales Distribution by Region', fontsize=16, fontweight='bold', color='purple')
plt.xlabel('Region', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Profit Distribution by Category Boxplot**

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='category', y='profit', data=df, palette='pastel')
plt.title('Profit Distribution by Category', fontsize=16, fontweight='bold', color='purple')
plt.xlabel('Category', fontsize=14)
plt.ylabel('Profit', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Profit vs Sales Scatter Plot by Category**

# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='sales', y='profit', hue='category', alpha=0.6)
plt.title('Profit vs Sales Scatter Plot by Category', fontsize=16, fontweight='bold', color='purple')
plt.xlabel('Sales', fontsize=12)
plt.ylabel('Profit', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Sales by Category and Segment (Stacked Bar Chart)**

# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Grouping the data
stacked_data = df.groupby(['category', 'segment'])['sales'].sum().unstack().fillna(0)

# Plot
stacked_data.plot(kind='bar', stacked=True, figsize=(10,6), colormap='Pastel1')

plt.title('Sales by Category and Segment (Stacked Bar Chart)', fontsize=16, fontweight='bold', color='purple')
plt.xlabel('Category',  fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.legend(title='Segment')
plt.xticks(rotation=0)
plt.grid(True, color='gray', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Profit by Region and Category (Heatmap)**

# %%
# Group the data
heatmap_data = df.groupby(['region', 'category'])['profit'].sum().unstack().fillna(0)

# Plot heatmap
plt.figure(figsize=(12, 7))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="magma", linewidths=0.5)

plt.title('Profit by Region and Category (Heatmap)', fontsize=16, fontweight='bold', color='purple')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Region', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary and Conclusion**

# %% [markdown]
# - Summary of My Data Visualizations
#
# In this project, I examined different methods for visualizing sales and profit data across various regions, product categories, customer segments, and over time. Below are a brief summary of each visualization and the insights I gained from them:
# -
#
# Sales by Region (Bar Chart)
# This chart showed how total sales differ across different geographic regions. It made it easy to spot which areas, like parts of the US, are doing well and which might have room to gro- w.
#
# Sales and Profit by Category (Bar Chart)
# Upon analyzing product categories, I discovered that Technology leads in both sales and profitability, with Furniture and Office Supplies closely trailing. Now this revelation enabled me to understand not only the popularity of specific products but also their profitabi- lity.
#
# Top 10 Products by Sales (Horizontal Bar Chart)
# Arranging the best-selling products in a horizontal format facilitated the reading of lengthy product names. This is highlighting key items driving sales, such as smartphones and executive-  chairs.
#
# Sales Distribution by Segment (Pie Chart)
# The pie chart demonstrated that the Consumer segment represents the most significant share of sales, surpassing fifty percent, thereby emphasizing the sectors where marketing work could be focused in the most productive po- ssible way.
#
# Numerical Features Correlation Heatmap
# This heatmap showed how sales, profit, quantity, discount, and shipping cost relate to each other. For example, it revealed that discounts tend to lower profit, and higher sales generally mean more - quantity sold.
#
# Monthly Sales Trend (Line Chart)
# Monitoring sales over multiple years, this chart showed fluctuations throughout the months, illustrating overall trends and seasonal patterns and these are more beneficial for forecast- ing and planning.
#
# Sales Distribution by Region (Boxplot)
# This boxplot gave a deeper look into sales variability in each region, showing median sales and highlighting outliers. Understanding this helps see how stable or volatile sales are-  in different areas.
#
# Profit Distribution by Category (Boxplot)
# Here I learned how profits vary within categories, with some showing losses. The plot also showed which categories have more consistent profits and w- hich carry higher risk.
#
# Profit vs Sales Scatter Plot by Category
# This scatter plot highlighted the relationship between sales and profit across categories. While most show positive correlation, some high sales didn't lead to profit, possibly due to-  heavy discounts or costs.
#
# Sales by Category and Segment (Stacked Bar Chart)
# Breaking down sales by category and customer segment revealed which segmen, s drive sales in each category—for example, the Consumer segmen- t dominates Technology sales.
#
# Profit by Category and Region (Heatmap)
# The heatmap gave a thorough presentation of financial health and made it easier for one to identify high-performing regions and products by displaying profits across various product categories and geographical areas.
#
# In summary, I successfully delivered a comprehensive narrative regarding sales and profit performance across multiple dimensions, such as category, geography, segment, and time. By utilizing appropriate visualizations, including bar charts for comparisons, heatmaps and scatter plots for illustrating relationships, as well as boxplots for depicting distributions, I was able to pinpoint significant trends, opportunities, and risks essential for informed business decision making.
#
# This project deepened my understanding of how powerful visualisation can be in turning complicated data into clear, actionable insights that anyone can understand.
